# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Задание 1

# %%
img = cv.imread("D:/PyProjects/NeuroDrone/datasets/dataset/images/2b3489f8-12.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
# Create a black image
img = np.zeros((512,512,3), np.uint8)
# Draw a diagonal blue line with thickness of 5 px

cv.line(img, (0,0), (512, 512), (134, 154, 200), 7)

cv.rectangle(img, (384,0), (510,128), (0,255,0), 3)
cv.circle(img, (447,63), 63, (0,0,255), -1)
cv.ellipse(img, (256,256), (100,50), 0, 0, 270, 255,-1)

pts = np.array([[10,5],[20,30],[70,20],[50,10]], np.int32)
pts = pts.reshape((-1,1,2))
cv.polylines(img,[pts],True,(0,255,255))
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img, 'OpenCV', (10,500), font, 4, (255,255,255), 2, cv.LINE_AA)

plt.imshow(img)
plt.show()

# %% [markdown]
# ## Задание 2

# %%
e1 = cv.getTickCount()
img1 = cv.imread("D:/PyProjects/NeuroDrone/datasets/dataset/images/2b3489f8-12.jpg")
cv.setUseOptimized(True)
print(cv.useOptimized())
for i in range(5,49,2):
    img1 = cv.medianBlur(img1,i)
e2 = cv.getTickCount()
time = (e2 - e1)/ cv.getTickFrequency()
time
# Out:
# True
# 1.7535049

# %%
img1 = cv.imread("D:/PyProjects/NeuroDrone/datasets/dataset/images/2b3489f8-12.jpg")
cv.setUseOptimized(False)
print(cv.useOptimized())
e1 = cv.getTickCount()
for i in range(5,49,2):
    img1 = cv.medianBlur(img1,i)
e2 = cv.getTickCount()
t = (e2 - e1)/cv.getTickFrequency()
t
# Out:
# False
# 1.8059144

# %%
x = 5
# %timeit y = x ** 2
# Out:
# 126 ns ± 0.519 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit y = x * x
# Out:
# 67.7 ns ± 1.69 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
z = np.uint8([5])
# %timeit y=z*z
# Out:
# 1.24 μs ± 27.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %timeit y=np.square(z)
# Out:
# 1.28 μs ± 15.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
img = cv.imread("D:/PyProjects/NeuroDrone/datasets/dataset/images/2b3489f8-12.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
# %timeit z = cv.countNonZero(img)
# Out:
# 32.5 μs ± 1.54 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit z = np.count_nonzero(img)
# Out:
# 43.1 μs ± 1.86 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Задание 3 находится в файле **camera_task.py**
