# %% [markdown]
# # Часть 1

# %% [markdown]
# ## Задача 6.1

# %% [markdown]
# В отчетном году себестоимость товарной продукции составила
# 450,2 млн. руб., что определило затраты на 1 руб. товарной продукции – 0,89 руб.
# В плановом году затраты на один руб. товарной продукции установлены в 0,85
# руб. Объем производства продукции будет увеличен на 8 %.
# Определите себестоимость товарной продукции планового года.
#
# ![image.png](attachment:image.png)

# %%
s_1 = 450_200_000
p_1 = 0.89
p_2 = 0.85

#рост объема на 8%
v_1 = s_1 / p_1

v_2 = 1.08 * v_1

s_2 = v_2 * p_2
s_2
# Out:
# 464363595.505618

# %% [markdown]
# ## Задача 6.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(((60 - 50) / (60)) * 100, "%", "1 квартал")
print(((60 - 52) / (60)) * 100, "%", "2 квартал")
print(((60 - 48) / 60) * 100, "%", "3 квартал")
# Out:
# 16.666666666666664 % 1 квартал
# 13.333333333333334 % 2 квартал
# 20.0 % 3 квартал

# %% [markdown]
# # Часть 2

# %% [markdown]
# ## Задача 7.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
C_post = 600
c_ed = 0.5
c_per = 0.3

q = C_post / (c_ed - c_per)
q
# Out:
# 3000.0

# %% [markdown]
# ## Задача 7.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
M = 0.1
c_poln = 0.35

V = 6000
S_pred = 2500
R_pred = 0.15
NDS = 0.2

R_p = (S_pred * R_pred) / (c_poln * V)
C_opt = c_poln * (1 + R_p)
c_otp = C_opt + (C_opt - (M)) * NDS
c_otp
# Out:
# 0.475
